# %%
import pandas as pd
df = pd.read_csv('sample_04.csv')
df.head(2)
# Out:
#   Prospect_Outcome Renewal_Impact_Due_to_Price_Increase Other_Complaint  \
# 0              NaN                                  NaN             NaN
# 1              NaN                                  NaN             NaN
#
#   Mentioned_Competitors crm_customer_complained  \
# 0                   NaN                     NaN
# 1                   NaN                     NaN
#
#   crm_negative_customer_experience crm_dissatisfaction_with_support  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
#
#   crm_financial_hardship_mentioned cc_business_struggles_financial_hardship  \
# 0                              NaN                                      NaN
# 1                              NaN                                      NaN
#
#   cc_contractor_sentiment cc_contractor_sentiment_issues_score  Status_Scores  \
# 0                     NaN                                  NaN            0.0
# ...

# %%
df = df.dropna(subset=['Prospect_Outcome'])

# %%
len(df)
# Out:
# 20681

# %%
df.to_csv('sample_04.csv', index=False)
